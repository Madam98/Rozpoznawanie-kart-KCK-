# %% [markdown]
# Komentarz:
#
# Aby poprawnie rozpoznawać karty będziemy musieli najpierw rozpoznawać kontury pojawiających się kart na obrazie. Kiedy karty zostaną już rozpoznane trzeba będzie porównać numer oraz kształt figury znajdujący się na karcie. W tym celu będziemy porównywać numer i kształt znajdujący się w lewym górnym/prawym dolnym rogu karty

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from skimage import(io, morphology, data, measure, img_as_ubyte, exposure)

folder_name = os.getcwd()
dir_name = "\examples"
location_name = folder_name + dir_name
card_list = os.listdir(location_name)

final_list = [location_name + "\\" + i for i in card_list]
cards = [io.imread(i) for i in final_list]

card_subplot, axes = plt.subplots(nrows=4, ncols=4, figsize=(15,5))
counter = 0
for i in range(4):
    for j in range(4):
        axes[i, j].imshow(cards[counter])
        axes[i, j].grid(False)
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        counter += 1
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-a752fe1821f1> in <module>
#      16 for i in range(4):
#      17     for j in range(4):
# ---> 18         axes[i, j].imshow(cards[counter])
#      19         axes[i, j].grid(False)
#      20         axes[i, j].set_xticks([])
#
# IndexError: list index out of range

# %%
from skimage import io, morphology, img_as_ubyte, exposure
from skimage.feature import canny, match_descriptors, ORB, plot_matches
from skimage.color import rgb2hsv
import os
import glob
import logging
import matplotlib.pyplot as plt
from skimage import transform as tf
from skimage.filters.rank import (threshold, median)
from skimage.morphology import (erosion, disk, dilation, square)
from scipy import ndimage
from skimage import measure
import numpy as np

algorithm = ORB() # <--https://scikit-image.org/docs/stable/auto_examples/features_detection/plot_orb.html#sphx-glr-auto-examples-features-detection-plot-orb-py

#SIZES
CANNY_SIGMA     = 1.0
EXAMPLES_FOLDER = "\examples"
CARDS_FOLDER    = "\cards"
color = ['kier', 'karo', 'trefl', 'pik']
types = ['as', 'dwa', 'trzy', 'cztery', 'pieć', 'sześć', 'siedem', 'osiem', 'dziewięć', 'dziesięć', 'walet', 'dama', 'król']

def readFolder(folder_name, dir_name):
    location_name = folder_name + dir_name
    system_list = os.listdir(location_name)
    return system_list

def takeFinalLocation(card, folder, location_name):
    final_name = location_name + "\\" + folder + "\\" + card
    return final_name

def loadExampleCards(card, location_name):
    folder = EXAMPLES_FOLDER
    location = takeFinalLocation(card, folder, location_name)
    print("Loanding pattern: " + card)
    card = io.imread(location)
    
    #modyfikacja władowanego wzoru
    card_hsv = rgb2hsv(card)
    card_value = card_hsv[:,:,2]
    card_no_noise = (median(img_as_ubyte(card_value), disk(2)))
    percentile_card = (2, 7)
    per1, per2 = np.percentile(card_no_noise, percentile_card)
    card_percentile_intensity = exposure.rescale_intensity(card_no_noise, in_range=(per1, per2))
    card_dilation = canny(card_percentile_intensity, 5.5)
    dilation(card_dilation, square(1), out = card_dilation)
    card_subplot, axes = plt.subplots(figsize=(15, 5))
    card_subplot = plt.imshow(canny(card_dilation, sigma = CANNY_SIGMA), cmap='gray')
    plt.show()
    
    #add end dilation array to return
 
    #z_patterns.append([card_dilation, obj_desc, obj_key, location_name])
    
    return card_dilation

def loadImages(card, location_name):
    location = takeFinalLocation(card, location_name)
    print("Loading image: " + card)
    card = io.imread(location)
    
    #modyfikacja władowanego wzoru
    #rozszerzyć i polepszyć!
    img = color.rgb2gray(card)
    
    temp = img
    temp = canny(temp, 2.0)
    temp = morphology.remove_small_objects(temp, 1400)
    card_countour = measure.find_contours(temp, 1.0) #<--- return Find iso-valued contours in a 2D array for a given level value.
    
    #mając zidentyfikowany kontur karty musimy wykryć znajdujący się wzór na niej
    #znajduje się ono zawsze w dwóch miejscach (lewy górny i prawy dolny róg)
    
    #mając tablicę konturu najlepiej wziąć początkowe wartości - górna lewa strona (sprawdzić)
    
    y_min = card_countour = card_countour[0]
    x_min = card_countour = card_countour[0]
    

def main():
    folder_name = os.getcwd()
    
    #READ EXAMPLE PATTERNS
    examples_list = readFolder(folder_name, EXAMPLES_FOLDER)
    print('Reading patterns...: ')
    CARD_EXAMPLES = []
    for i in range(len(examples_list)):
        CARD_EXAMPLES.append(loadExampleCards(examples_list[i], folder_name))
        print(CARD_EXAMPLES)
    
    #READ CARD TO RECOGNISE
    images_list = readFolder(folder_name, CARDS_FOLDER)
    print('Reading cards...: ')
    CARD_SCENES = []
    for i in range(len(images_list)):
        CARD_SCENES.append(loadCards(images_list[i], folder_name))

    #temp = ndimage.binary_fill_holes(temp)

    #rozszerzyc o dodanie scen
    
    for i in :
        
        #rozszerzyc
        
        for j in range(len(patterns)):
            
        
        
    
if __name__ == '__main__':
    main()
# Out:
# Reading patterns...:
# Loanding pattern: IMG20211202133108.jpg
# [array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])]
# Loanding pattern: IMG20211202133243.jpg
# [array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]]), array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
# ...
